# %%
nome = 'Antônio Carlos'
print('Olá', nome, 'seja bem-vindo!')

if nome == 'Antônio Carlos':
    nome = 'Carlos'
    print(f'Olá {nome}, seja bem vindo')
# Out:
# Olá Antônio Carlos seja bem-vindo!
# Olá Carlos, seja bem vindo

# %%
pessoa = 'João da Silva'
print('Olá', pessoa)
# Out:
# Olá João da Silva

# %%
def solution(inputString = ''):
    if inputString == inputString.__reversed__():
        return True
    else:
        return False
    
solution('aaasaaa')

# %%
numero = 1
numero + 2
numero + 99
# Out:
# 100
